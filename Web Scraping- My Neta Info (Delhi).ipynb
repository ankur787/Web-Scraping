# %%
#install.packages('data.table', repos='http://cran.us.r-project.org')

# %%
library(data.table)
library(rvest)
library(stringi)
library(stringr)
library(openxlsx)
# Out:
# Loading required package: xml2
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2

# %%
details_df = data.frame(Name = character(), ContactNumber = character(), 
                Email =character(), Age = character(), Relation = character(),Education = character(), 
                Profession= character(), Address = character(), Party = character(),Location = character(), 
                        State = character(),Year = numeric())

# %%
i <- sprintf("%03d", 1:10)  
url <- paste("http://myneta.info/delhi2015/candidate.php?candidate_id=", i, sep = "")

for(i in seq_along(url)){
  print(i)
  read1 <- read_html(url[i])
  
  name <- read1 %>%
    html_node('.main-title , .grid_2 , b')%>%
    html_text()

    
    location <- read1 %>%
      html_node('h5 , .grid_3~ .alpha+ .alpha , .alpha:nth-child(5)')%>%
      html_text()
    location <- substring(location, regexpr(":", location) + 1)
    
    party <- read1 %>%
      html_node('h5+ .alpha')%>%
      html_text()
    party <- substring(party, regexpr(":", party) + 1)
    
    education <- read1 %>%
      html_node('.left-margin')%>%
      html_text()
    
    profession <- read1 %>%
      html_node('p , .left-margin')%>%
      html_text()
    profession  <- substr(x = profession,start = 18,stop = 74)
    
    address <- read1 %>%
      html_node('.alpha:nth-child(6)')%>%
      html_text()
    address <-substring(address, regexpr(":", address) + 1)
    
    txt2 <- read1 %>%
      html_nodes(".grid_3~ .alpha+ .alpha , .alpha:nth-child(5)")%>%
      html_text()
    
    contactNum <- txt2[2]
    contactNum <- substring(contactNum, regexpr(":", contactNum) + 1)
    print(contactNum)
    
    age<- txt2[1]
    age <- substring(age, regexpr(":", age) + 1)
    
    txt <- read1 %>%
      html_nodes(".grid_2")%>%
      html_text()
    email <- txt[5]
    email <- substring(email, regexpr(":", email) + 1)
    
    relation<- txt[2]
    relation <- substring(relation, regexpr(":", relation) + 1)
    
    state <- 'Delhi'
    
    year <- 2015
    
    df = data.frame(Name = character(), ContactNumber = character(), 
                 Email =character(), Age = character(), Relation = character(),Education = character(), 
                 Profession= character(), Address = character(), Party = character(),Location = character(), 
                        State = character(),Year = numeric())
    
    df = data.frame(State = state, Year = year, Name = name, Location = location, Party=party, Relation= relation, Age = age,Address = address, 
                Email=email, ContactNumber= contactNum, Profession = profession,
                Education= education)
    
    details_df <- rbind(details_df,df)  
}
# Out:
# [1] 1
# [1] " 9891141121"
# [1] 2
# [1] " 9213169339, "
# [1] 3
# [1] " 7838323279 , 8130054326"
# [1] 4
# [1] " 9968405499"
# [1] 5
# [1] " 9999021066"
# [1] 6
# [1] NA
# [1] 7
# [1] " 9999433966"
# [1] 8
# [1] " 9818363726"
# [1] 9
# [1] " 9212577786"
# [1] 10
# [1] NA

# %%
#setwd("C:/Users/user/Desktop/R")

# %%
details_df
# Out:
#    State Year Name               Location
# 1  Delhi 2015 D.K.CHOPRA         \n        MEHRAULI  (SOUTH)\n
# 2  Delhi 2015 NAFE SINGH RAJPUT  \n        BURARI  (NORTH)\n
# 3  Delhi 2015 SHYAM BHARTEEY     \n        UTTAM NAGAR  (SOUTH-WEST)\n
# 4  Delhi 2015 MANAGER CHAURASIYA \n        BURARI  (NORTH)\n
# 5  Delhi 2015 RAM BABU           \n        BAWANA  (NORTH-WEST)\n
# 6  Delhi 2015 Disclaimer:        NA
# 7  Delhi 2015 BEHEN PREETI       \n        SHAHDARA  (EAST)\n
# 8  Delhi 2015 KASHI NATH SAH     \n        PALAM  (SOUTH-WEST)\n
# 9  Delhi 2015 RAKESH             \n        TRILOKPURI  (EAST)\n
# 10 Delhi 2015 Disclaimer:        NA
#    Party
# 1  IND\n
# 2  IND\n
# 3  Gareeb Aadmi Party\n
# 4  SUCI(C)\n
# 5  Rashtriya Bahujan Hitay Party \n
# 6  NA
# 7  IND\n
# 8  IND\n
# 9  Gareeb Aadmi Party\n
# 10 NA
#    Relation                                          Age
# 1  \n            Dr R.N.Chopra \n                     61\n
# 2  \n            Sh.Ramphal Rajput \n                 41\n
# 3  \n            Ram Autar \n                         45\n
# 4  \n            Lt. Mr. Bandhu Chaurasiya\n          45\n
# 5  \n            Sh. Chhedi Lal\n                     64\n
# 6  NA                                                NA
# 7  \n            Prit Pal Singh\n                     55\n
# 8  \n            Chanderma Sah\n                      39\n
# 9  \n            Sri Dal Chand \n                     40\n
# 10 NA                                                NA
#    Address
# 1  \n            A/A 1039 ,Vasant Kunj \n
# 2  \n            Resident-475A,G.NO.3, Main Bus stand Vill-Jharoda Mazara Burari Delhi -110084 .\n
# 3  \n            R-21, Mohan Garden ,uttam Nagar N.D.-51\n
# 4  \n            R/o.5492/1, G.No.115/18B B-Block, Baba Colony, Burari\n
# 5  \n            H. No. 115, Deep Vihar, Phase-1, Block B, Prahlad Pur, Banger Village, Delhi-42\n
# 6  NA
# 7  \n            C-228, First Floor, Vivek Vihar, Delhi-110095\n
# 8  \n            RZC-3/32A, Main Guru Dwara Road, Mahavir Enclave, New Delhi 45\n
# 9  \n            Resident Of -29/429 , Block -29 Trilokpuri Delhi \n
# 10 NA
#    Email
# 1  seniorcitizenwelfare@gmail.com
# 2  nafesinghrajput @gmail.com, aazadnafesinghrajput@gmail.com
# 3  sbgap1@gmail.com
# 4  sucicburari@gmail.com
# 5
# 6  NA
# 7  behenpreeti@gmail.com
# 8  kashinathsah75@gmail.com
# 9  rakeshkumar.gareebaadmiparty@gmail.com
# 10 NA
#    ContactNumber
# 1   9891141121
# 2   9213169339,
# 3   7838323279 , 8130054326
# 4   9968405499
# 5   9999021066
# 6  NA
# 7   9999433966
# 8   9818363726
# 9   9212577786
# 10 NA
#    Profession                                                Education
# 1  Retired Spouse Profession:\n                              Graduate
# 2  Data Entry Operetor Spouse Profession:Housewife\n         12th Pass
# 3  Business & Social ServiceSpouse Profession:Parlour Bussin 12th Pass
# 4  Social WorkerSpouse Profession:House Wife\n               12th Pass
# 5  Own Work, Shop KeeperSpouse Profession:House Wife\n       8th Pass
# 6   primary source for the data used for these reports is th NA
# 7  Social WorkerSpouse Profession:\n                         Illiterate
# 8  Self EmployedSpouse Profession:House Wife\n               10th Pass
# 9  Business Spouse Profession:Housewife\n                    12th Pass
# 10  primary source for the data used for these reports is th NA

# %%
#write.xlsx(details_df, file = "delhi123_myneta_info.xlsx")
